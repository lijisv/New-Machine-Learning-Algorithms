# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris_df = pd.DataFrame(iris.data,columns=iris.feature_names)
iris_df["Species"]=iris.target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# X and Y values are
X= iris_df.drop(['Species'],axis=1)
y= iris_df['Species']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# check the shape of X_train and X_test
print("The dimension of X_train is {}".format(X_train.shape))
print("The dimension of X_test is {}".format(X_test.shape))
# Out:
# The dimension of X_train is (105, 4)
# The dimension of X_test is (45, 4)

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 1.0
# R-squared Test  : 1.0
# MSE : 0.0
# RMSE : 0.0

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
# Out:
# [Text(453.375, 504.7714285714286, 'X[3] <= 0.8\ngini = 0.664\nsamples = 105\nvalue = [38, 31, 36]'),
#  Text(383.625, 427.11428571428576, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(523.125, 427.11428571428576, 'X[3] <= 1.75\ngini = 0.497\nsamples = 67\nvalue = [0, 31, 36]'),
#  Text(348.75, 349.4571428571429, 'X[2] <= 5.35\ngini = 0.208\nsamples = 34\nvalue = [0, 30, 4]'),
#  Text(279.0, 271.8, 'X[3] <= 1.65\ngini = 0.117\nsamples = 32\nvalue = [0, 30, 2]'),
#  Text(139.5, 194.14285714285717, 'X[2] <= 4.95\ngini = 0.064\nsamples = 30\nvalue = [0, 29, 1]'),
#  Text(69.75, 116.48571428571432, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]'),
#  Text(209.25, 116.48571428571432, 'X[3] <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(139.5, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(279.0, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(418.5, 194.14285714285717, 'X[0] <= 5.8\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(348.75, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(488.25, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(418.5, 271.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(697.5, 349.4571428571429, 'X[2] <= 4.85\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32]'),
#  Text(627.75, 271.8, 'X[1] <= 3.1\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(558.0, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(697.5, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(767.25, 271.8, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
dt_classifier = DecisionTreeClassifier(criterion="entropy",max_depth=5)
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.9809523809523809
# R-squared Test  : 0.9777777777777777
# MSE : 0.022222222222222223
# RMSE : 0.14907119849998599

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
# Out:
# [Text(418.5, 498.3, 'X[2] <= 2.6\nentropy = 1.58\nsamples = 105\nvalue = [38, 31, 36]'),
#  Text(334.8, 407.70000000000005, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(502.20000000000005, 407.70000000000005, 'X[3] <= 1.75\nentropy = 0.996\nsamples = 67\nvalue = [0, 31, 36]'),
#  Text(334.8, 317.1, 'X[2] <= 5.35\nentropy = 0.523\nsamples = 34\nvalue = [0, 30, 4]'),
#  Text(251.10000000000002, 226.5, 'X[1] <= 2.55\nentropy = 0.337\nsamples = 32\nvalue = [0, 30, 2]'),
#  Text(167.4, 135.89999999999998, 'X[2] <= 4.45\nentropy = 0.722\nsamples = 10\nvalue = [0, 8, 2]'),
#  Text(83.7, 45.299999999999955, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(251.10000000000002, 45.299999999999955, 'entropy = 1.0\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(334.8, 135.89999999999998, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22, 0]'),
#  Text(418.5, 226.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(669.6, 317.1, 'X[2] <= 4.85\nentropy = 0.196\nsamples = 33\nvalue = [0, 1, 32]'),
#  Text(585.9, 226.5, 'X[0] <= 5.95\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(502.20000000000005, 135.89999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(669.6, 135.89999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(753.3000000000001, 226.5, 'entropy = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
dt_classifier = Linear
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
