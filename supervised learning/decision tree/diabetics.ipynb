# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df.drop(['Outcome'],axis=1)
Y = df['Outcome']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=17)

# %%
clf  = DecisionTreeClassifier()
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train,Y_train)

score = dt_classifier.score(X_train,Y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, Y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(Y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 1.0
# R-squared Test  : 0.7056277056277056
# MSE : 0.2943722943722944
# RMSE : 0.5425608669746597

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
# Out:
# [Text(462.83175442913387, 525.48, 'X[1] <= 143.5\ngini = 0.454\nsamples = 537\nvalue = [350, 187]'),
#  Text(222.67138287401576, 489.24, 'X[7] <= 28.5\ngini = 0.366\nsamples = 419\nvalue = [318, 101]'),
#  Text(157.3494094488189, 453.0, 'X[5] <= 45.4\ngini = 0.196\nsamples = 218\nvalue = [194, 24]'),
#  Text(125.76968503937009, 416.76, 'X[6] <= 0.898\ngini = 0.177\nsamples = 214\nvalue = [193, 21]'),
#  Text(88.9724409448819, 380.52, 'X[0] <= 7.5\ngini = 0.139\nsamples = 200\nvalue = [185, 15]'),
#  Text(80.18503937007874, 344.28, 'X[1] <= 131.5\ngini = 0.131\nsamples = 199\nvalue = [185, 14]'),
#  Text(41.74015748031496, 308.04, 'X[5] <= 30.9\ngini = 0.102\nsamples = 185\nvalue = [175, 10]'),
#  Text(17.5748031496063, 271.8, 'X[6] <= 0.672\ngini = 0.02\nsamples = 101\nvalue = [100, 1]'),
#  Text(8.78740157480315, 235.56, 'gini = 0.0\nsamples = 92\nvalue = [92, 0]'),
#  Text(26.36220472440945, 235.56, 'X[5] <= 24.05\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(17.5748031496063, 199.32, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(35.1496062992126, 199.32, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(65.90551181102363, 271.8, 'X[5] <= 31.3\ngini = 0.191\nsamples = 84\nvalue = [75, 9]'),
#  Text(57.118110236220474, 235.56, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(74.69291338582677, 235.56, 'X[4] <= 38.0\ngini = 0.174\nsamples = 83\nvalue = [75, 8]'),
#  Text(52.7244094488189, 199.32, 'X[1] <= 109.5\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(35.1496062992126, 163.07999999999998, 'X[4] <= 34.0\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(26.36220472440945, 126.83999999999997, 'X[3] <= 40.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(17.5748031496063, 90.60000000000002, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(35.1496062992126, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(43.93700787401575, 126.83999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(70.2992125984252, 163.07999999999998, 'X[5] <= 34.65\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(61.51181102362205, 126.83999999999997, 'X[2] <= 61.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(52.7244094488189, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(70.2992125984252, 90.60000000000002, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(79.08661417322836, 126.83999999999997, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(96.66141732283465, 199.32, 'X[6] <= 0.609\ngini = 0.069\nsamples = 56\nvalue = [54, 2]'),
#  Text(87.8740157480315, 163.07999999999998, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(105.4488188976378, 163.07999999999998, 'X[2] <= 50.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(96.66141732283465, 126.83999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(114.23622047244095, 126.83999999999997, 'X[0] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(105.4488188976378, 90.60000000000002, 'X[2] <= 71.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(96.66141732283465, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(114.23622047244095, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(123.0236220472441, 90.60000000000002, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(118.62992125984252, 308.04, 'X[4] <= 30.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(101.05511811023622, 271.8, 'X[7] <= 21.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text
ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(426.18897637795277, 271.8, 'X[2] <= 62.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(417.40157480314963, 235.56, 'X[4] <= 203.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(408.6141732283465, 199.32, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(426.18897637795277, 199.32, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(434.9763779527559, 235.56, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(443.76377952755905, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(508.5708661417323, 308.04, 'X[0] <= 7.5\ngini = 0.486\nsamples = 72\nvalue = [30, 42]'),
#  Text(461.3385826771654, 271.8, 'X[6] <= 0.262\ngini = 0.5\nsamples = 49\nvalue = [24, 25]'),
#  Text(452.55118110236225, 235.56, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(470.12598425196853, 235.56, 'X[6] <= 0.965\ngini = 0.498\nsamples = 45\nvalue = [24, 21]'),
#  Text(445.96062992125985, 199.32, 'X[7] <= 32.5\ngini = 0.475\nsamples = 36\nvalue = [22, 14]'),
#  Text(423.99212598425197, 163.07999999999998, 'X[4] <= 163.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(415.20472440944883, 126.83999999999997, 'X[7] <= 31.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(406.4173228346457, 90.60000000000002, 'X[6] <= 0.387\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(397.62992125984255, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(415.20472440944883, 54.360000000000014, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(423.99212598425197, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(432.7795275590551, 126.83999999999997, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(467.92913385826773, 163.07999999999998, 'X[6] <= 0.441\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(459.1417322834646, 126.83999999999997, 'X[7] <= 41.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(441.5669291338583, 90.60000000000002, 'X[4] <= 81.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(432.7795275590551, 54.360000000000014, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(450.35433070866145, 54.360000000000014, 'X[3] <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(441.5669291338583, 18.120000000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(459.1417322834646, 18.120000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(476.7165354330709, 90.60000000000002, 'X[2] <= 83.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(467.92913385826773, 54.360000000000014, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(485.503937007874, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(476.7165354330709, 126.83999999999997, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(494.2913385826772, 199.32, 'X[5] <= 31.25\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(485.503937007874, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(503.07874015748035, 163.07999999999998, 'X[3] <= 47.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(494.2913385826772, 126.83999999999997, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(511.8661417322835, 126.83999999999997, 'X[1] <= 124.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(503.07874015748035, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(520.6535433070867, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(555.8031496062993, 271.8, 'X[6] <= 0.508\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(547.0157480314961, 235.56, 'X[6] <= 0.276\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(529.4409448818898, 199.32, 'X[5] <= 31.8\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(520.6535433070867, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(538.228346456693, 163.07999999999998, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(564.5905511811023, 199.32, 'X[5] <= 36.25\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(555.8031496062993, 163.07999999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(573.3779527559055, 163.07999999999998, 'X[0] <= 9.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(564.5905511811023, 126.83999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(582.1653543307087, 126.83999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(564.5905511811023, 235.56, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(702.992125984252, 489.24, 'X[1] <= 155.5\ngini = 0.395\nsamples = 118\nvalue = [32, 86]'),
#  Text(645.8740157480315, 453.0, 'X[7] <= 41.0\ngini = 0.493\nsamples = 41\nvalue = [18, 23]'),
#  Text(612.9212598425197, 416.76, 'X[5] <= 41.65\ngini = 0.49\nsamples = 28\nvalue = [16, 12]'),
#  Text(590.9527559055118, 380.52, 'X[1] <= 146.5\ngini = 0.434\nsamples = 22\nvalue = [15, 7]'),
#  Text(573.3779527559055, 344.28, 'X[7] <= 28.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(564.5905511811023, 308.04, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(582.1653543307087, 308.04, 'X[3] <= 36.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(573.3779527559055, 271.8, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(590.9527559055118, 271.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(608.5275590551181, 344.28, 'X[6] <= 0.165\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(599.740157480315, 308.04, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(617.3149606299213, 308.04, 'X[1] <= 154.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(608.5275590551181, 271.8, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(626.1023622047244, 271.8, 'X[4] <= 320.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(617.3149606299213, 235.56, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(634.8897637795276, 235.56, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(634.8897637795276, 380.52, 'X[1] <= 153.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(626.1023622047244, 344.28, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(643.6771653543308, 344.28, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(678.8267716535433, 416.76, 'X[6] <= 0.251\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(670.0393700787401, 380.52, 'X[0] <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(661.2519685039371, 344.28, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(678.8267716535433, 344.28, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(687.6141732283464, 380.52, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(760.1102362204725, 453.0, 'X[5] <= 29.85\ngini = 0.298\nsamples = 77\nvalue = [14, 63]'),
#  Text(713.9763779527559, 416.76, 'X[7] <= 28.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(705.1889763779528, 380.52, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(722.7637795275591, 380.52, 'X[5] <= 26.65\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(713.9763779527559, 344.28, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(731.5511811023622, 344.28, 'X[7] <= 36.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(722.7637795275591, 308.04, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(740.3385826771654, 308.04, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(806.244094488189, 416.76, 'X[6] <= 2.233\ngini = 0.222\nsamples = 63\nvalue = [8, 55]'),
#  Text(797.4566929133858, 380.52, 'X[5] <= 46.1\ngini = 0.2\nsamples = 62\nvalue = [7, 55]'),
#  Text(775.488188976378, 344.28, 'X[2] <= 93.0\ngini = 0.158\nsamples = 58\nvalue = [5, 53]'),
#  Text(757.9133858267717, 308.04, 'X[6] <= 0.343\ngini = 0.109\nsamples = 52\nvalue = [3, 49]'),
#  Text(749.1259842519686, 271.8, 'X[6] <= 0.27\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(740.3385826771654, 235.56, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(757.9133858267717, 235.56, 'X[4] <= 33.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(749.1259842519686, 199.32, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(766.7007874015749, 199.32, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(766.7007874015749, 271.8, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(793.0629921259842, 308.04, 'X[2] <= 99.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(784.2755905511812, 271.8, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(801.8503937007874, 271.8, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(819.4251968503937, 344.28, 'X[4] <= 177.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(810.6377952755906, 308.04, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(828.2125984251969, 308.04, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(815.0314960629921, 380.52, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
dt_classifier = DecisionTreeClassifier(criterion="entropy",max_depth=4)
dt_classifier.fit(X_train,Y_train)

score = dt_classifier.score(X_train,Y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, Y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(Y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.7914338919925512
# R-squared Test  : 0.7489177489177489
# MSE : 0.2510822510822511
# RMSE : 0.5010810823432182

# %%
from sklearn import tree
plt.figure(figsize=(20,15))
tree.plot_tree(dt_classifier,filled=True,class_names=True)
# Out:
# [Text(558.0, 733.86, 'X[1] <= 123.5\nentropy = 0.932\nsamples = 537\nvalue = [350, 187]\nclass = y[0]'),
#  Text(279.0, 570.78, 'X[7] <= 28.5\nentropy = 0.678\nsamples = 313\nvalue = [257, 56]\nclass = y[0]'),
#  Text(139.5, 407.70000000000005, 'X[5] <= 30.9\nentropy = 0.382\nsamples = 175\nvalue = [162, 13]\nclass = y[0]'),
#  Text(69.75, 244.62, 'X[0] <= 7.5\nentropy = 0.147\nsamples = 95\nvalue = [93, 2]\nclass = y[0]'),
#  Text(34.875, 81.54000000000008, 'entropy = 0.085\nsamples = 94\nvalue = [93, 1]\nclass = y[0]'),
#  Text(104.625, 81.54000000000008, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(209.25, 244.62, 'X[4] <= 122.5\nentropy = 0.578\nsamples = 80\nvalue = [69, 11]\nclass = y[0]'),
#  Text(174.375, 81.54000000000008, 'entropy = 0.662\nsamples = 64\nvalue = [53, 11]\nclass = y[0]'),
#  Text(244.125, 81.54000000000008, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = y[0]'),
#  Text(418.5, 407.70000000000005, 'X[5] <= 26.25\nentropy = 0.895\nsamples = 138\nvalue = [95, 43]\nclass = y[0]'),
#  Text(348.75, 244.62, 'X[5] <= 9.65\nentropy = 0.25\nsamples = 24\nvalue = [23, 1]\nclass = y[0]'),
#  Text(313.875, 81.54000000000008, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(383.625, 81.54000000000008, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = y[0]'),
#  Text(488.25, 244.62, 'X[1] <= 99.5\nentropy = 0.949\nsamples = 114\nvalue = [72, 42]\nclass = y[0]'),
#  Text(453.375, 81.54000000000008, 'entropy = 0.61\nsamples = 40\nvalue = [34, 6]\nclass = y[0]'),
#  Text(523.125, 81.54000000000008, 'entropy = 0.999\nsamples = 74\nvalue = [38, 36]\nclass = y[0]'),
#  Text(837.0, 570.78, 'X[1] <= 154.5\nentropy = 0.979\nsamples = 224\nvalue = [93, 131]\nclass = y[1]'),
#  Text(697.5, 407.70000000000005, 'X[5] <= 27.35\nentropy = 0.995\nsamples = 144\nvalue = [78, 66]\nclass = y[0]'),
#  Text(627.75, 244.62, 'X[1] <= 151.5\nentropy = 0.381\nsamples = 27\nvalue = [25, 2]\nclass = y[0]'),
#  Text(592.875, 81.54000000000008, 'entropy = 0.235\nsamples = 26\nvalue = [25, 1]\nclass = y[0]'),
#  Text(662.625, 81.54000000000008, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(767.25, 244.62, 'X[7] <= 41.5\nentropy = 0.994\nsamples = 117\nvalue = [53, 64]\nclass = y[1]'),
#  Text(732.375, 81.54000000000008, 'entropy = 0.992\nsamples = 85\nvalue = [47, 38]\nclass = y[0]'),
#  Text(802.125, 81.54000000000008, 'entropy = 0.696\nsamples = 32\nvalue = [6, 26]\nclass = y[1]'),
#  Text(976.5, 407.70000000000005, 'X[5] <= 29.85\nentropy = 0.696\nsamples = 80\nvalue = [15, 65]\nclass = y[1]'),
#  Text(906.75, 244.62, 'X[2] <= 87.0\nentropy = 0.971\nsamples = 15\nvalue = [6, 9]\nclass = y[1]'),
#  Text(871.875, 81.54000000000008, 'entropy = 0.89\nsamples = 13\nvalue = [4, 9]\nclass = y[1]'),
#  Text(941.625, 81.54000000000008, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = y[0]'),
#  Text(1046.25, 244.62, 'X[0] <= 7.5\nentropy = 0.58\nsamples = 65\nvalue = [9, 56]\nclass = y[1]'),
#  Text(1011.375, 81.54000000000008, 'entropy = 0.688\nsamples = 49\nvalue = [9, 40]\nclass = y[1]'),
#  Text(1081.125, 81.54000000000008, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = y[1]')]

# %%
Y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
